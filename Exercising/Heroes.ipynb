# %%
import pandas as pd
import seaborn as sns

# %%
heroes = pd.read_excel("../TrainingData/heroes.xlsx", sheet_name='original')

# %%
heroes.head()
# Out:
#        Unit_name   Castle Level  Attack  Defence  Minimum Damage  \
# 0    AzureDragon  Neutral     7      50       50              70
# 1  CrystalDragon  Neutral     7      40       40              60
# 2     RustDragon  Neutral     7      30       30              50
# 3   FaerieDragon  Neutral     7      20       20              20
# 4      Archangel   Castle    7+      30       30              50
#
#    Maximum Damage  Health  Speed  Growth  AI_Value   Gold Additional_item  \
# 0              80    1000     19       1     78845  30000      Mercury,20
# 1              75     800     16       1     39338  20000      Crystal,10
# 2              50     750     17       1     26433  15000       Sulfur,14
# 3              30     500     15       1     19580  10000           Gem,8
# 4              50     250     18       1      8776   5000           Gem,3
#
#                                    Special_abilities
# 0  Dragon,Flying,Breath,Fear,Resistlvl1вЂ“3spells...
# ...

# %%
heroes["Castle"].unique()
# Out:
# array(['Neutral', 'Castle', 'Dungeon', 'Rampart', 'Tower', 'Inferno',
#        'Conflux', 'Stronghold', 'Fortress', 'Necropolis'], dtype=object)

# %%
heroes[heroes["Castle"].isin(['Tower', 'Castle'])]
# Out:
#             Unit_name  Castle Level  Attack  Defence  Minimum Damage  \
# 4           Archangel  Castle    7+      30       30              50
# 7               Titan   Tower    7+      24       24              40
# 13              Angel  Castle     7      20       20              50
# 19              Giant   Tower     7      19       16              40
# 22          NagaQueen   Tower    6+      16       13              30
# 24           Champion  Castle    6+      16       16              20
# 27               Naga   Tower     6      16       13              20
# 29           Cavalier  Castle     6      15       15              15
# 48        MasterGenie   Tower    5+      12       12              13
# 50              Genie   Tower     5      12       12              13
# 57             Zealot  Castle    5+      12       10              10
# 59           ArchMage   Tower    4+      12        9               7
# 64               Mage   Tower     4      11        8               7
# ...

# %%
heroes["Gold"][0].dtype
# Out:
# dtype('int64')

# %%
nations = ['Castle', 'Dungeon', 'Rampart', 'Tower', 'Inferno',
       'Conflux', 'Stronghold', 'Fortress', 'Necropolis']

# %%
heroes[heroes['Castle'] != 'Neutral']
# Out:
#        Unit_name    Castle Level  Attack  Defence  Minimum Damage  \
# 4      Archangel    Castle    7+      30       30              50
# 5    BlackDragon   Dungeon    7+      25       25              40
# 6     GoldDragon   Rampart    7+      27       27              40
# 7          Titan     Tower    7+      24       24              40
# 8      ArchDevil   Inferno    7+      26       28              30
# ..           ...       ...   ...     ...      ...             ...
# 135   Troglodyte   Dungeon     1       4        3               1
# 136        Gnoll  Fortress     1       3        5               2
# 137        Pixie   Conflux     1       2        2               1
# 138          Imp   Inferno     1       2        3               1
# 139      Gremlin     Tower     1       3        3               1
#
#      Maximum Damage  Health  Speed  Growth  AI_Value  Gold Additional_item  \
# 4                50     250     18       1      8776  5000           Gem,3
# ...

# %%
sns.relplot(x = "Gold", y="AI_Value", hue = "Castle", col = "Castle", col_wrap = 3, height = 2.5, data = heroes[heroes["Castle"].isin(nations)])
sns.set_style("darkgrid")
